# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to **"Bike Demand Visualization Project"** which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.
#
# This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
#
#
#
# #### Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# **"weather_code" category description:**
# * 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# * 2 = scattered clouds / few clouds
# * 3 = Broken clouds
# * 4 = Cloudy
# * 7 = Rain/ light Rain shower/ Light rain
# * 10 = rain with thunderstorm
# * 26 = snowfall
# * 94 = Freezing Fog
# ---
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc.  Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.

# %% [markdown]
# # Tasks

# %% [markdown]
# ### 1.Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2.Read dataset

# %%
df = pd.read_csv("store_sharing.csv",encoding="utf-8")
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %% [markdown]
# ### 3.Check missing values and if there are any dublicate rows or not.

# %%
df.duplicated().value_counts()
# Out:
# False    17414
# dtype: int64

# %%
df.isnull().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %% [markdown]
# ### 4.Plot the distribution of various discrete features on (Season, haliday, weekend and weathercode)

# %%
# season
sns.countplot(x="season", data=df)
plt.show()

# %%
# is_holiday
sns.countplot(x="is_holiday", data=df)
plt.show()

# %%
# is_weekend
sns.countplot(x="is_weekend", data=df)
plt.show()

# %%
# weather_code
sns.countplot(x="weather_code",data=df)
plt.show()

# %% [markdown]
# ### 5.Look at the data type of each variable, transform `timestamp` in type, and set it as index.

# %%
df2 = df.set_index(keys =df.timestamp).drop("timestamp",axis = 1)
df2
# Out:
#                       cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...  ...  ...    ...         ...           ...
# 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0
# 2015-01-04 01:00:00         0.0         1.0     3.0
# 2015-01-04 02:00:00         0.0         1.0     3.0
# 2015-01-04 03:00:00         0.0         1.0     3.0
# 2015-01-04 04:00:00         0.0         1.0     3.0
# ...                         ...         ...     ...
# 2017-01-03 19:00:00         0.0         0.0     3.0
# 2017-01-03 20:00:00         0.0         0.0     3.0
# 2017-01-03 21:00:00         0.0         0.0     3.0
# 2017-01-03 22:00:00         0.0         0.0     3.0
# 2017-01-03 23:00:00         0.0         0.0     3.0
#
# [17414 rows x 9 columns]

# %% [markdown]
# - Tam 2 yillik bir timestamp var. `year, month, day_of_month, day_of_week, hour` bilgilerini alarak feature engineering yapalim

# %% [markdown]
# ### 6.Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)

# %% [markdown]
# you can use strftime('%Y-%m') for year_mount

# %%
from datetime import datetime

# %%
df.timestamp = pd.to_datetime(df.timestamp)

# %%
df2.index = pd.DatetimeIndex(df.timestamp)

# %%
type(df2.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
x = pd.DataFrame(df.timestamp.dt.strftime('%Y-%m'))
x = x.set_index(df.timestamp)
type(x.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df2["year_month"] = x
df2.year_month
# Out:
# timestamp
# 2015-01-04 00:00:00    2015-01
# 2015-01-04 01:00:00    2015-01
# 2015-01-04 02:00:00    2015-01
# 2015-01-04 03:00:00    2015-01
# 2015-01-04 04:00:00    2015-01
#                         ...
# 2017-01-03 19:00:00    2017-01
# 2017-01-03 20:00:00    2017-01
# 2017-01-03 21:00:00    2017-01
# 2017-01-03 22:00:00    2017-01
# 2017-01-03 23:00:00    2017-01
# Name: year_month, Length: 17414, dtype: object

# %%
df2["year"] = pd.DatetimeIndex(df.timestamp).year

# %%
df2["month"] = pd.DatetimeIndex(df.timestamp).month

# %%
df2["day_of_month"] = pd.DatetimeIndex(df.timestamp).day

# %%
df2["day_of_week"] = pd.DatetimeIndex(df.timestamp).day_of_week

# %%
df2["hour"] = pd.DatetimeIndex(df.timestamp).hour

# %%
df2.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season year_month  year  month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 01:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 02:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 03:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 04:00:00         0.0         1.0     3.0    2015-01  2015      1
#
#                      day_of_month  day_of_week  hour
# timestamp
# 2015-01-04 00:00:00             4            6     0
# 2015-01-04 01:00:00             4            6     1
# 2015-01-04 02:00:00             4            6     2
# 2015-01-04 03:00:00             4            6     3
# 2015-01-04 04:00:00             4            6     4

# %% [markdown]
# ### 7.Visualize the correlation with a heatmap

# %%
# for all variables 
plt.figure(figsize=(16,11))
sns.heatmap(df2.corr(),annot=True,cmap="coolwarm")
plt.show()

# %%
x = df2.corrwith(df2.cnt).sort_values(ascending=False)
x
# Out:
# cnt             1.000000
# t1              0.388798
# t2              0.369035
# hour            0.324423
# wind_speed      0.116295
# month           0.063757
# year            0.010046
# day_of_month   -0.017887
# is_holiday     -0.051698
# day_of_week    -0.068688
# is_weekend     -0.096499
# season         -0.116180
# weather_code   -0.166633
# hum            -0.462901
# dtype: float64

# %%
# for the target variable

# %% [markdown]
# ### 8. Visualize the correlation of the target variable and the other features with barplot

# %%
#with pandas
plt.figure(figsize=(15,7))
sns.set_style(style="darkgrid")
sns.barplot(x,x.index)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 9.Plot bike shares over time use lineplot

# %%
plt.figure(figsize=(16,7))
sns.lineplot(df2.index,df2.cnt)
# Out:
# <AxesSubplot:xlabel='timestamp', ylabel='cnt'>

# %% [markdown]
# ### 10.Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot)

# %%
# with lineplot
plt.figure(figsize=(16,6))
sns.lineplot(df2.year_month.value_counts().index, df2.groupby("year_month").cnt.sum())
plt.xticks(rotation=45)
plt.show()

# %%
# with lineplot
plt.figure(figsize=(12,6))
sns.lineplot(data=df2,x=df2.month,y=df2.cnt)
plt.show()

# %%
# with pointplot
plt.figure(figsize=(14,6))
sns.pointplot(data=df2,x=df2.month,y=df2.cnt)
plt.show()

# %%
# with barplot
plt.figure(figsize=(12,8))
sns.barplot(data=df2,x=df2.month,y=df2.cnt)
plt.show()

# %% [markdown]
# ### 11.Plot bike shares by hours on (holidays, weekend, season)

# %%
# with lineplot (*whether it is a holiday or not*)
plt.figure(figsize=(16,6))
sns.lineplot(data=df2,x=df2.hour,y=df2.cnt,hue=df2.is_holiday)
plt.show()

# %%
# with lineplot (*You may want to see seasonal breakdowns*)
plt.figure(figsize=(16,6))
sns.lineplot(data=df2,x=df2.hour,y=df2.cnt,hue=df2.season)
plt.show()

# %%
# with pointplot
plt.figure(figsize=(16,10))
plt.subplot(4,1,1)
sns.pointplot(data=df2,x=df2.hour,y=df2.cnt)
plt.subplot(4,1,2)
sns.pointplot(data=df2,x=df2.hour,y=df2.cnt,hue=df2.is_holiday)
plt.subplot(4,1,3)
sns.pointplot(data=df2,x=df2.hour,y=df2.cnt,hue=df2.is_weekend)
plt.subplot(4,1,4)
sns.pointplot(data=df2,x=df2.hour,y=df2.cnt,hue=df2.season)
plt.show()

# %% [markdown]
# ### 12.Plot bike shares by day of week
# - You may want to see whether it is a holiday or not

# %%
# with barplot
plt.figure(figsize=(9,5))
sns.barplot(data=df2,x=df2.day_of_week,y=df2.cnt,hue=df2.is_weekend)
plt.show()

# %%
# with pointplot
plt.figure(figsize=(13,7))
plt.subplot(2,1,1)
sns.pointplot(data=df2,x=df2.day_of_week,y=df2.cnt)
plt.subplot(2,1,2)
sns.pointplot(data=df2,x=df2.day_of_week,y=df2.cnt,hue=df2.season)
plt.show()

# %% [markdown]
# ### 13.Plot bike shares by day of month

# %%
#with lineplot
plt.figure(figsize=(13,5))
sns.lineplot(data=df2,x=df2.day_of_month,y=df2.cnt)
plt.show()

# %% [markdown]
# ### 14.Plot bike shares by year
# ### Plot bike shares on holidays by seasons

# %%
# with barplot
plt.figure(figsize=(10,6))
sns.barplot(data=df2,x=df2.year,y=df2.cnt.where(df2.is_holiday == 1.0))
plt.show()

# %%
# with barplot
plt.figure(figsize=(10,6))
sns.barplot(data=df2,x=df2.season.where(df2.is_holiday == 1.0),y=df2.cnt.where(df2.is_holiday == 1.0))
plt.show()

# %% [markdown]
# ### 15.Visualize the distribution of bike shares by weekday/weekend with piechart and barplot

# %%
df2.is_weekend.value_counts()
# Out:
# 0.0    12444
# 1.0     4970
# Name: is_weekend, dtype: int64

# %%
df2.is_weekend.value_counts(normalize=True)
# Out:
# 0.0    0.714597
# 1.0    0.285403
# Name: is_weekend, dtype: float64

# %%
# pie chart
plt.pie(df2.is_weekend.value_counts(),labels=["weekday","weekend"],autopct="%.1f%%")
plt.show()

# %%
percentage = df.is_weekend.value_counts(normalize=True)
round(percentage[0]*100,1)
# Out:
# 71.5

# %%
value = df.is_weekend.value_counts()
value[1]
# Out:
# 4970

# %%
text = [f"%{round(percentage[0]*100,1)} - {value[0]}",f"%{round(percentage[1]*100,1)} - {value[1]}"]
type(text[0])
# Out:
# str

# %%
# with countplot
plt.figure(figsize=(8,5))
sns.countplot(df2.is_weekend)
for i,v in enumerate(text):
    plt.text(i,value[i],s=v, ha="center",va="bottom",fontdict={"size": 12})

# %% [markdown]
# ### 16.Plot the distribution of weather code by seasons

# %%
# with countplot
sns.countplot(data =df2,x=df2.weather_code)
plt.show()

# %%
# with catplot
sns.catplot(data=df2,x="weather_code",col="season",kind="count")
plt.show()

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
