# %% [markdown]
# # WITH PANDAS AND MATPLOTLIB

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
#
# 1. Number of people by gender
# 1. Kill weapon
# 1. Age of killed people
# 1. Race of killed people
# 1. Killed People According to Races (Pie Chart)
# 1. Most common 15 Name or Surname of killed people
#
# <br>

# %% [markdown]
# read data
#
# if didn't work you can use this parameters: encoding="windows-1252"

# %%
kill = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252")

# %% [markdown]
# ## 1: Plot number of people by gender

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
y = kill.groupby("gender").gender.count().sort_values(ascending=False)
y
# Out:
# gender
# M    2428
# F     107
# Name: gender, dtype: int64

# %%
x = kill.gender.value_counts().index
len(x)
x
# Out:
# Index(['M', 'F'], dtype='object')

# %%
# with matplotlib
plt.xticks(range(len(x)),x)
plt.title("Gender Distribution")
for index, value in enumerate(y):
    plt.text(index, value, str(value), ha="center",va="bottom")
plt.bar(x,y)
plt.show()

# %% [markdown]
# ## 2: Plot 7 most common kill weapons

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
weapons = kill.groupby("armed").armed.count().sort_values(ascending=False).head(7)
weapons
# Out:
# armed
# gun               1398
# knife              373
# vehicle            177
# unarmed            171
# undetermined       117
# toy weapon         104
# unknown weapon      18
# Name: armed, dtype: int64

# %%
ind = pd.Series(weapons.index)
ind
# Out:
# 0               gun
# 1             knife
# 2           vehicle
# 3           unarmed
# 4      undetermined
# 5        toy weapon
# 6    unknown weapon
# Name: armed, dtype: object

# %%
for index, value in enumerate(weapons):
    print(index,value)
# Out:
# 0 1398
# 1 373
# 2 177
# 3 171
# 4 117
# 5 104
# 6 18

# %%
# with matplotlib
plt.figure(figsize =(12,7))
plt.bar(ind, weapons,)
for index, value in enumerate(weapons):
    plt.text(index, value, str(value), ha="center",va="bottom")
plt.show()

# %%
# with matplotlib
plt.figure(figsize =(12,7))
plt.bar(ind, weapons)
for index, value in enumerate(weapons):
    plt.text(index, value, str(value), ha="center",va="bottom")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 3: Plot number of age of killed people under two groups : Under 25 and Above 25

# %%
kill["age_cat"] = kill.age.apply(lambda x : "above25" if x > 25 else "below25")

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  age_cat
# 0  Not fleeing        False  above25
# ...

# %%
age_c = kill.age_cat.value_counts()
age_c
# Out:
# above25    1905
# below25     630
# Name: age_cat, dtype: int64

# %%
age_c.index
# Out:
# Index(['above25', 'below25'], dtype='object')

# %%
# with matplotlib
plt.bar(age_c.index, age_c)
for index, value in enumerate(age_c):
    plt.text(index, value, str(value), ha="center", va="bottom")

# %% [markdown]
# ## 4: Plot number of killed poeple by race

# %%
race_c = kill.groupby("race").race.count().sort_values(ascending=False)
race_c
# Out:
# race
# W    1201
# B     618
# H     423
# A      39
# N      31
# O      28
# Name: race, dtype: int64

# %%
# with matplotlib
plt.bar(race_c.index,race_c)
for index, value in enumerate(race_c):
    plt.text(index, value, str(value), ha="center", va="bottom")
plt.title("Race of killed people",fontdict={"size":15,"color":"blue"})
plt.show()

# %% [markdown]
# ## 5: Killed People According to Races (Pie Chart)

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  age_cat
# 0  Not fleeing        False  above25
# ...

# %%
kill.race.unique()
# Out:
# array(['A', 'W', 'H', 'B', 'O', nan, 'N'], dtype=object)

# %%
kill.groupby("race",dropna=False).race.count().sort_values(ascending=False)
# Out:
# race
# W      1201
# B       618
# H       423
# A        39
# N        31
# O        28
# NaN       0
# Name: race, dtype: int64

# %% [markdown]
# Problem: missing value on race column.

# %% [markdown]
# **INSTRUCTION-1: Drop the all raws that contain missing value (dropna)**

# %%
kill.dropna(inplace=True)

# %%
kill.shape
# Out:
# (2254, 15)

# %% [markdown]
# **INSTRUCTION-2: Demonstrate Race Ratio of Killed People by a Pie Chart (You can use Matplotlib)**

# %%
race_c2 = kill.race.value_counts()
race_c2
# Out:
# W    1168
# B     592
# H     401
# A      36
# N      29
# O      28
# Name: race, dtype: int64

# %%
race_c2.index
# Out:
# Index(['W', 'B', 'H', 'A', 'N', 'O'], dtype='object')

# %%
race_c2.values
# Out:
# array([1168,  592,  401,   36,   29,   28], dtype=int64)

# %%
race_c2.size
# Out:
# 6

# %%
# matplotlib
explode1 = (0,0,0.1,0,0,0)
plt.figure(figsize=(25,11))
plt.pie(race_c2.values,labels=race_c2.index,startangle=70,autopct="%.1f%%",explode=explode1)
plt.show()

# %%
explode1 = (0,0,0.2,0.3,0.2,0.1)
plt.figure(figsize=(25,11))
plt.pie(race_c2.values,labels=race_c2.index,startangle=70,autopct="%.1f%%",explode=explode1)
plt.show()

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
name_list = []
for i in kill.name:
    name_list.append(i.split(" "))
all_names = []
all_surnames = []

# %%
for i in name_list:
    all_surnames.append(i[-1])
    i.remove(i[-1])

# %%
for i in name_list:
    for n in range(len(i)):
        all_names.append(i[n])

# %%
len(all_names)
# Out:
# 3512

# %%
len(all_surnames)
# Out:
# 2535

# %%
len(name_list)
# Out:
# 2535

# %%
all_names_pd = pd.Series(all_names)
all_names_pd.head()
# Out:
# 0      Tim
# 1    Lewis
# 2      Lee
# 3     John
# 4     Paul
# dtype: object

# %%
all_surnames_pd = pd.Series(all_surnames)
all_surnames_pd.head()
# Out:
# 0       Elliot
# 1       Lembke
# 2     Quintero
# 3      Hoffman
# 4    Rodriguez
# dtype: object

# %%
all_names_pd.value_counts()
# Out:
# Michael       90
# David         57
# James         55
# TK            51
# Robert        48
#               ..
# Hugo           1
# Tuan           1
# Jozefowicz     1
# Tashfeen       1
# Deltra         1
# Length: 1186, dtype: int64

# %%
all_names_pd.value_counts()[9]
# Out:
# 41

# %%
kill.name.isnull().value_counts()
# Out:
# False    2535
# Name: name, dtype: int64
